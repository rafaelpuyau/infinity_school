# %% [markdown]
# # Aula 01

# %% [markdown]
# ## Importando a biblioteca Pandas

# %%
import pandas as pd

# %% [markdown]
# ## Lendo o **Dataset** sobre o faturamento de vinhos

# %%
vinhos = pd.read_csv('/content/drive/MyDrive/2022/Data Science/faturamento_quinzena_nov2021.csv', sep=';')

# %% [markdown]
# ## Conhecendo o **dataset**

# %%
# Saber quantas linhas e colunas meu dataframe tem
vinhos.shape
# Out:
# (45, 5)

# %%
# Listar as colunas do dataframe
vinhos.columns
# Out:
# Index(['data', 'estilo', 'quantidade de garrafas', 'preço da garrafa',
#        'total'],
#       dtype='object')

# %%
# Conhecer os tipos de dados do meu dataframe
vinhos.dtypes
# Out:
# data                       object
# estilo                     object
# quantidade de garrafas      int64
# preço da garrafa          float64
# total                     float64
# dtype: object

# %%
# Pegando mais informações
vinhos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   data                    45 non-null     object
#  1   estilo                  45 non-null     object
#  2   quantidade de garrafas  45 non-null     int64
#  3   preço da garrafa        45 non-null     float64
#  4   total                   45 non-null     float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 1.9+ KB

# %%
# Pegando uma maior detalhamento com o método describe()
vinhos.describe()
# Out:
#        quantidade de garrafas  preço da garrafa        total
# count               45.000000         45.000000    45.000000
# mean                 8.244444        100.296667   863.980667
# std                  4.156898         35.544601   614.730403
# min                  1.000000         75.000000    75.890000
# 25%                  5.000000         75.000000   379.450000
# 50%                  8.000000         75.890000   758.900000
# 75%                 10.000000        150.000000  1050.000000
# max                 20.000000        150.000000  3000.000000

# %%
# Recupero as 5 primeiras linhas do dataframe
vinhos.head()
# Out:
#          data     estilo  quantidade de garrafas  preço da garrafa    total
# 0  2021-11-01      tinto                       7            150.00  1050.00
# 1  2021-11-01     branco                       4             75.00   300.00
# 2  2021-11-01  espumante                       5             75.89   379.45
# 3  2021-11-02      tinto                       3            150.00   450.00
# 4  2021-11-02     branco                       2             75.00   150.00

# %% [markdown]
# ## Explorando o **dataframe**

# %%
# Pegando os valores únicos da coluna estilo
vinhos['estilo'].unique()
# Out:
# array(['tinto', 'branco', 'espumante'], dtype=object)

# %%
# Selecionando 3 colunas do dataframe e fazendo um slide
# para retornar 3 linhas
vinhos[['data', 'estilo', 'preço da garrafa']][1:4]
# Out:
#          data     estilo  preço da garrafa
# 1  2021-11-01     branco             75.00
# 2  2021-11-01  espumante             75.89
# 3  2021-11-02      tinto            150.00

# %%
# Retornando o tipo de dado
estilo = vinhos['estilo']
type(estilo)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## Criando um dataframe

# %%
pd.DataFrame({
    'Yes': [50, 21],
    'No': [10, 15]
})
# Out:
#    Yes  No
# 0   50  10
# 1   21  15

# %%
pd.DataFrame({
    'Professores': ['Rafael', 'Xavier', 'Pascoal', 'Murilo'],
    'e-Mail': ['rafael@email.com', 'xavier@email.com', 'pascoal@email.com', 'murilo@email.com']
})
# Out:
#   Professores             e-Mail
# 0      Rafael   rafael@email.com
# 1      Xavier   xavier@email.com
# 2     Pascoal  pascoal@email.com
# 3      Murilo   murilo@email.com
