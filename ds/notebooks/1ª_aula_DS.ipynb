# %% [markdown]
# # O que é Data Science?
#
# __Definição de mercado__: é o processo de exploração, manipulação e análise dos dados para a __descoberta__ e __previsão__ através da criação de _hipóteses_, _testes_ e _validação_ com o objetivo de responder e/ou fazer recomendações capazes de serem diferenciais de negócio.
#
# Todo esse processo precisa ter um forte __embasamento estatístico__ e __matemático__ e ser __diretamente ligado ao negócio__, além de poder ser feito de forma __escalável__ e __replicável__.

# %% [markdown]
# ## Como rodar e executar um código de Data Science?

# %% [markdown]
# As boas práticas de programação em python recomendam que devemos criar um ambiente virtual, quando rodamos localmente - em nosso computador - para isolarmos nosso ambiente de trabalho e assim podermos instalar todas as bibliotecas necessárias.
#
# Você já sabe como criar seu ambiente virtual usando o módulo __venv__.
#
# Porém, temos como rodar / executar nossos códigos utilizando o Google Collaboratory. Neste caso, as principais bibliotecas já vem instaladas e o ambiente já está pronto para utilizarmos.

# %% [markdown]
# ### Rodando localmente

# %% [markdown]
# Para rodar localmente, em nosso próprio computador / notebook / laptop, devemos criar um ambiente virtual dentro da nossa pasta de trabalho.
#
# Execute o comando `python -m venv IN` para criar seu ambiente virtual. Perceba que __IN__ é o nome deste ambiente e você poderá substituí-lo por qualquer outro que desejar.
#
# __OBS__ : pode ser que receba um _WARNING_ para atualizar a versão do gerenciador de pacotes pip. Isso não interferirá em nada, mas se desejar atualizá-lo, execute o seguinte comando: `python -m pip install --upgrade pip`

# %% [markdown]
# #### Ativando o ambiente virtual
#
# * __Em máquinas windows__: `IN\Scripts\activat`
# * __Em máquinas linux e mac__: `source IN/bin/activate`

# %% [markdown]
# #### Desativando o ambiente virtual
#
# * __Para todos os sistemas basta executar `deactivate` para desativar o ambiente virtual.

# %% [markdown]
# #### Instalando as bibliotecas
#
# Agora com o ambiente virtual ativo, é hora de instalar as 2 bibliotecas que utilizaremos neste módulo: __pandas__ e __matplotlib__.
#
# Execute o comando `pip install pandas matplotlib` e o __pip__ buscará no repositório _www.pypi.org_ as últimas versões destes pacotes.

# %% [markdown]
# #### Onde executar?
#
# Já que estamos rodado localmente, temos mais liberdade para executar nossos códigos no editor de código de nossa preferência como por exemplo:
#
# * Vim
# * Emacs
# * Jupyter Notebook
# * VS Code
# * PyCharm
#
# __ATENÇÃO__: antes de abrir nosso editor de código preferido, certifique-se de ativar o ambiente virtual no qual instalamos as bibliotecas de Data Science.

# %% [markdown]
# ##### VIM / NeoVim
#
# Toda distribuição linux já vem com o __vi__ instalado por padrão. As mais recentes, trazem o __vi improved__ instalado.
#
# Você, também, pode instalar o NeoVim, que é um _fork_ do projeto __vi__. Ambos os editores tem diversos _plugins_ que dão suporte à python e facilitam a edição dos códigos como _syntax highlight_, _formatação_ entre outros.
#
# __Em distros baseadas em Debian__ : `sudo apt install neovim`
#
#
# __Em distros baseadas em RedHat__ : `sudo dnf install neovim`

# %% [markdown]
# ##### Emacs
#
# Se você preferir outro editor, em modo texto, como alternativa ao __vi__, poderá utilizar o _Emacs_.
#
# __Em distros baseadas em Debian__ : `sudo apt install emacs`
#
# __Em distros baseadas em RedHat__ : `sudo apt install emacs`

# %% [markdown]
# ##### Jupyter Notebook
#
# Caso prefira algum editor gráfico ao invés dos editores de modo texto, há a alternativa do _Jupyter Notebook_ que roda numa janela do seu navegador e trabalha com células, onde podemos escrever textos e códigos.
#
# Porém, devemos instalar esse pacote dentro do nosso ambiente virtual previamente criado e ativado.
#
# Execute o comando `pip install jupyter`, aguarde a instalação deste pacote e de suas dependências.
#
# Após concluída a instalação, rode o seguinte comando : `jupyter notebook`. Ele irá abrir uma aba no seu navegador padrão.
#
# Para abrir um novo notebook, basta clicar em __New__ e escolher __Python 3 (ipykernel)__
#
# ![jupyter_1.png](data:image/png;base64,...)
#
# Com isso, você terá a tela a seguir:
#
# ![jupyter_2.png](data:image/png;base64,...)

# %% [markdown]
# ##### VS Code
#
# Esté é um editor muito popular, leve e de fácil utlização e aprendizado. É o editor adotado pela __Infinity School__.
#
# Você poderá fazer o download diretamente deste link _https://code.visualstudio.com/_.
#
# Com o arquivo de instalação salvo no seu computador, basta seguir os passos da instalação.

# %% [markdown]
# ##### PyCharm
#
# Este editor é muito poderoso e popular entre os programadores python.
#
# Você poderá fazer o download diretamente deste link _https://www.jetbrains.com/pycharm/_.
#
# Clique no botão _download_ e depois escolha a versão _Community_.
#
# Com o arquivo de instalação salvo no seu computador, basta seguir os passos da instalação.

# %% [markdown]
# ### Rodando na nuvem

# %% [markdown]
# Para este módulo, utilizaremos o _Google Collaboratory_. Se você ainda não tiver uma conta Google, providencie para que possa prosseguir no módulo.

# %% [markdown]
# ##### Google Colab
#
# Siga os passos a seguir para criar o seu primeiro notebook
#
# 1. Abra seu Google Drive
# 2. Clique no botão __New__
# 3. Depois selecione a opção __More__
# 4. Finalmente clique em __Google Colaboratory__
#
# __ATENÇÃO__ : Caso não apareça a opção do _Google Colaboratory_, utilize a opção __Connect more apps__.
#
# Na tela que aparecer, basta digitar no campo de pesquisa e digitar _Google Colab_ e pressione _enter_. Clique sobre a opção que aparecer e depois em _Install_.
#
# Agora basta seguir o passo-a-passo anterior para abrir seu 1º notebook.

# %% [markdown]
# ##### Principais comandos / atalhos Google Colab
#
# ###### Para otimizar sua codificação
#
# Esses são os principais atalhos que deverá saber:
#
# * `ctrl + enter` : roda a célula atual
# * `alt + enter` : roda a célula atual e cria uma célula em branco
# * `shift + enter` : roda a célula atual e vai para a próxima célula
# * `ctrl + m a` : insere uma célula acima da célula corrente
# * `ctrl + m b` : insere uma célula abaixo da célula corrente
# * `ctrl + m m` : alterna para o modo texto
# * `ctrl + m y` : alterna para o modo código
#
# __OBS__ : para mais atalhos, execute `ctrl + m h`

# %% [markdown]
# ## Colocando a mão no código

# %% [markdown]
# Para esta aula, vamos utilizar a biblioteca pandas.
# O Google Colab já disponibiliza ela pra gente, basta apenas importá-la.
#
# Por convenção, utilizamos o apelido (_alias_) __pd__ para esta biblioteca

# %% [markdown]
# ### Importação da biblioteca

# %%
import pandas as pd

# %% [markdown]
# Recomendamos sempre buscar ajuda na documentação oficial de cada linguagem e de suas respectivas bibliotecas.
#
# __DICA__ : Utilize o sinal de __?__ para obter ajuda sobre uma determinada função sem precisar sair do Google Colab. A ajuda será aberta no canto da direita.

# %% [markdown]
# ### Buscando ajuda para a função read_csv

# %%
pd.read_csv?

# %% [markdown]
# Após a importação da biblioteca _pandas_, precisamos ler o nosso _dataset_.
#
# * __Dataset__ : conjunto de dados que vamos trabalhar
#
# Para isso, a biblioteca _pandas_ no fornece diversas funções. Precisamos identificar o tipo de arquivo do nosso _dataset_ e chamar a função apropriada.
#
# Neste caso, nosso _dataset_ está no formato __CSV__, logo vamos utilizar a função `read_csv()` para ler e carregar o _dataset_.
#
# O caminho do _dataset_ em questão é esse `https://raw.githubusercontent.com/rafaelpuyau/infinity_school/main/ds/datasets/faturamento_quinzena_nov2021.csv`
#
# __OBS__ : repare que utilizaremos a letra __r__ antes da string (_Raw String_). Dessa forma estamos informando a função para tratar a string na sua "forma crua" sem querer interpretar nada dentro dela.
#
# Você tem a opção de carregar seu _dataset_ sem colocar o __r__, porém, recomenda-se utilizar a _raw string_ para garantirmos que a string passada para a função `read_csv` será tratada como uma string crua.
#
# __Encoding de Arquivos__
#
# Outra dica importante é conhecer qual é o _encoding_ do _dataset_ que iremos trabalhar. Normalmente, os encodings de datasets que receberemos estará como `UTF-8`, porém, pode acontecer de recebermos datasets com outros encodings e devemos passar isso para a função `read_csv` através do parâmetro `encoding`.
#
# * __Em máquina Windows__ : você deve fazer o download do _Notepad++_ (https://notepad-plus-plus.org/) e abrir o dataset com este programa. Ele tem uma opção no menu chamada _Encoding_ que irá mostrar qual é o encoding no arquivo em questão
#
# * __Em máquinas Linux e Mac__ : essa questão é mais fácil. Basta abrirmos um terminal e digitar o comando `file --mime-encoding arquivo.csv` para recebemos como resposta o encoding do arquivo.

# %% [markdown]
# ### Lendo o dataset

# %%
dataset = r'https://raw.githubusercontent.com/rafaelpuyau/infinity_school/main/ds/datasets/faturamento_quinzena_nov2021.csv'
df = pd.read_csv(dataset, sep=';')

# %% [markdown]
# Após o carregmento do _dataset_, chamamos o método `.head()` apenas para nos certificarmos que o _dataset_ foi carregado corretamente.
#
# O método `.head()` retorna as 5 primeiras linhas. Vale lembrar que você pode passar a quantidade de linhas que deseja ver passando este número entre parêntesis.

# %% [markdown]
# ### Retornando as 5 primeiras linhas do dataset

# %%
df.head()
# Out:
#          data     estilo  quantidade de garrafas  preço da garrafa    total
# 0  2021-11-01      tinto                       7            150.00  1050.00
# 1  2021-11-01     branco                       4             75.00   300.00
# 2  2021-11-01  espumante                       5             75.89   379.45
# 3  2021-11-02      tinto                       3            150.00   450.00
# 4  2021-11-02     branco                       2             75.00   150.00

# %% [markdown]
# Para obtermos uma descrição completa do _dataframe_, chamamos o método `info()`.
#
# Com este método, temos as seguintes informações:
#
# * o intervalo do index
# * o total de colunas
# * o nome de todas colunas
# * se há valores nulos ou não
# * o tipo de dado de cada coluna
#
# __OBS__: vale lembrar que o tipo de dado `object` é _string_

# %% [markdown]
# ### Coletando informações sobre o dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   data                    45 non-null     object
#  1   estilo                  45 non-null     object
#  2   quantidade de garrafas  45 non-null     int64
#  3   preço da garrafa        45 non-null     float64
#  4   total                   45 non-null     float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 1.9+ KB

# %% [markdown]
# O atributo `columns` retorna uma lista com o nome de todas as colunas do _dataframe_.
#
# Isso pode ser muito __útil__ quando queremos consultar, rapidamente, os nomes das colunas e, também, para copiar o nome de alguma coluna para uma seleção futura, evitando desta forma, erros de digitação ou acentuação na refrência a determinada coluna.

# %% [markdown]
# ### Pegando as colunas

# %%
df.columns
# Out:
# Index(['data', 'estilo', 'quantidade de garrafas', 'preço da garrafa',
#        'total'],
#       dtype='object')

# %% [markdown]
# Podemos melhorar o tipo de dado das colunas, para otimizar o uso de memória. Isto é muito útil, quando se está trabalhando com um conjunto de dados muito grande.
#
# __OBS__: durante o tratamento e o cálculo de dados, o dataframe fica em memória
#
# Neste caso, a coluna `preço da garrafa` está como `float64`, o que ocupa muito espaço em memória.
#
# A biblioteca __PANDAS__ nos ajuda neste sentido e fornece o método `to_numeric()`. Com este método, você passa a coluna e o parâmetro `downcast` que fará a convesão, sempre que possível, para o tipo de dado especificado.
#
# __Dica__:
#
# * use `integer` para colunas com valores numéricos inteiros
# * use `float` para colunas com valores numéricos com ponto flutuante

# %% [markdown]
# ### Alterand o tipo de dado de uma coluna númerica

# %%
df['preço da garrafa'] = pd.to_numeric(df['preço da garrafa'], downcast='float')

# %% [markdown]
# Após o uso do método `to_numeric`, chamamos novamente o método `info` e percebemos que, agora, a coluna `preço da garrafa` está como `float32`, um tipo de dados mais adequado para os valores desta coluna.
#
# __OBS__: com isso diminuímos o uso de memória do _dataframe_ em questão.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   data                    45 non-null     object
#  1   estilo                  45 non-null     object
#  2   quantidade de garrafas  45 non-null     int64
#  3   preço da garrafa        45 non-null     float32
#  4   total                   45 non-null     float64
# dtypes: float32(1), float64(1), int64(1), object(2)
# memory usage: 1.7+ KB

# %% [markdown]
# Agora que aprendemos a usar o método `to_numeric`, vamos aplicar, também, para a coluna `quantidade de garrafas`.
#
# Caso não se lembre, exatamente do nome da coluna, ou seja, como está escrita, recomenda-se invocar o atributo `columns` e a partir do retorno deste atributo, copiar o nome da coluna que desejamos.

# %%
df.columns
# Out:
# Index(['data', 'estilo', 'quantidade de garrafas', 'preço da garrafa',
#        'total'],
#       dtype='object')

# %% [markdown]
# Aqui usamos o método `to_numeric` na coluna `quantidade de garrafas`, fazendo o _downcast_ para `integer`.

# %%
df['quantidade de garrafas'] = pd.to_numeric(df['quantidade de garrafas'], downcast='integer')

# %% [markdown]
# Repare que agora, a coluna `quantidade de garrafas` está como `int8` ao invés do `int64` quando carregamos o _dataframe_ em memória.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   data                    45 non-null     object
#  1   estilo                  45 non-null     object
#  2   quantidade de garrafas  45 non-null     int8
#  3   preço da garrafa        45 non-null     float32
#  4   total                   45 non-null     float64
# dtypes: float32(1), float64(1), int8(1), object(2)
# memory usage: 1.4+ KB

# %% [markdown]
# ### Método Describe

# %% [markdown]
# Para conhecermos ainda mais o _dataset_ em que estamos trabalhando, podemos utilizar a função `describe`.
#
# O método describe() que nos dá, inicialmente, um resumo sobre as **Series** numéricas com as seguintes informações:
#
# * __count__ : mostra quantos registros / linhas há em nosso dataframe
# * __mean__ : mostra a média. Vale lembrar que a depender da coluna, esse valor pode não fazer muito sentido mas no nosso exemplo, a média se aplica as colunas de quantidade de garrafas, preço da garrafa e total.
# * __std__ : desvio padrão, esse tópico é abordado na especialização em Data Science
# * __min__ : valor mínimo
# * __os quartis__:
#     * __25%__ : 1º quadrante, significa que 25% dos dados estão abaixo de determinada quantidade. Ex: Olhando para a coluna de quantidade de garrafas, temos o valor de 5. Isso significa dizer que 25% dos registros do nosso dataframe estão abaixo de 5 garrafas.
#     * __50%__ : 2º quadrante, também conhecido como mediana. Metade dos registros do nosso dataframe estão abaixo de 8 garrafas, ainda olhando para a coluna de quantidade de garrafas.
#     * __75%__ : 3º quadrante, onde temos 75% dos registros do nosso dataframe abaixo de 10 garrafas.
# * __max__ : valor máximo

# %%
df.describe()
# Out:
#        quantidade de garrafas  preço da garrafa        total
# count               45.000000         45.000000    45.000000
# mean                 8.244444        100.296677   863.980667
# std                  4.156898         35.544601   614.730403
# min                  1.000000         75.000000    75.890000
# 25%                  5.000000         75.000000   379.450000
# 50%                  8.000000         75.889999   758.900000
# 75%                 10.000000        150.000000  1050.000000
# max                 20.000000        150.000000  3000.000000

# %% [markdown]
# Pode-se utilizar este método em uma **Series** numérica específica e, também, numa **Series** de strings, onde as informações retornadas são diferentes das **Series** numéricas. Assim, obtemos os seguintes valores:
#
# * __count__ : retorna quantas linhas que há no nosso dataframe
# * __unique__ : retorna os valores únicos encontrados nesta Serie específica
# * __top__ : retorno o "termo" encontrado com maior frequência. Vale ressaltar que esta informação retornará a primeira ocorrência, caso haja, mais termos com a mesma frequência.
# * __freq__ : retorna o número de ocorrências do no termo listados em __top__

# %%
df['estilo'].describe()
# Out:
# count        45
# unique        3
# top       tinto
# freq         15
# Name: estilo, dtype: object

# %% [markdown]
# ### Hora de praticar!

# %% [markdown]
# Quando sabemos que nosso _dataset_ possui uma coluna com valores de _data_, podemos passá-la ao parâmetro `parse_dates` no método `read_csv` que dessa forma já faz o _parse_.

# %%
arquivo_fat = r'https://raw.githubusercontent.com/rafaelpuyau/infinity_school/main/ds/datasets/faturamento_quinzena_nov2021.csv'
fat = pd.read_csv(arquivo_fat, sep=';', parse_dates=['data'])

# %% [markdown]
# O atributo `dtypes` retorna os tipos de dados de todas as colunas do _dataframe_

# %%
fat.dtypes
# Out:
# data                      datetime64[ns]
# estilo                            object
# quantidade de garrafas             int64
# preço da garrafa                 float64
# total                            float64
# dtype: object

# %% [markdown]
# __VALE LEMBRAR__ : sempre que precisar de ajuda, não precisa sair do _Google Colab_, basta colocar o __?__ após a chamada no método para que a ajuda seja exibida.

# %%
pd.read_csv?

# %% [markdown]
# Após a leitura do _dataset_, chamamos o método `head()` para saber se conseguimos carregar corretamente o _dataframe_.
#
# O método `head()` retorna as 5 primeiras linhas.

# %%
fat.head()
# Out:
#         data     estilo  quantidade de garrafas  preço da garrafa    total
# 0 2021-11-01      tinto                       7            150.00  1050.00
# 1 2021-11-01     branco                       4             75.00   300.00
# 2 2021-11-01  espumante                       5             75.89   379.45
# 3 2021-11-02      tinto                       3            150.00   450.00
# 4 2021-11-02     branco                       2             75.00   150.00

# %% [markdown]
# O atributo `shape` retorna uma __tupla__ com o número de _linhas_ e _colunas_ do _dataframe_.

# %%
fat.shape
# Out:
# (45, 5)

# %% [markdown]
# Se quisermos pegar somente o número de colunas do _dataframe_, acessaremos esse valor através do índice da __tupla__, que neste caso está no _indice 1_.

# %%
fat.shape[1]
# Out:
# 5

# %% [markdown]
# Podemos associar a leitura desses valores retornados pelo atributo `shape` com a função `print` para termos uma saída mais _descritiva_.

# %%
print(f'Nosso dataset tem {fat.shape[0]} linhas')
# Out:
# Nosso dataset tem 45 linhas

# %% [markdown]
# O método `info()` retorna um resumo do _dataframe_ em que estamos trabalhando

# %%
fat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   data                    45 non-null     object
#  1   estilo                  45 non-null     object
#  2   quantidade de garrafas  45 non-null     int64
#  3   preço da garrafa        45 non-null     float64
#  4   total                   45 non-null     float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 1.9+ KB

# %% [markdown]
# __VALE LEMBRAR__ : sempre que precisar de ajuda, não precisa sair do _Google Colab_, basta colocar o __?__ após a chamada no método para que a ajuda seja exibida.

# %%
pd.to_numeric?

# %% [markdown]
# Vamos alterar o tipo de dado da coluna `quantidade de garrafas` usando o método `to_numeric`.

# %%
fat['quantidade de garrafas'] = pd.to_numeric(fat['quantidade de garrafas'], downcast='integer')

# %% [markdown]
# Através do atributo `dtypes` temos os tipos de dados do _dataframe_

# %%
fat.dtypes
# Out:
# data                      datetime64[ns]
# estilo                            object
# quantidade de garrafas              int8
# preço da garrafa                 float64
# total                            float64
# dtype: object

# %% [markdown]
# Se quisermos descobrir os valores únicos de uma coluna, devemos usar o método `unique()`.
#
# Este método retorna um _array_ com os valores únicos.

# %%
fat['estilo'].unique()
# Out:
# array(['tinto', 'branco', 'espumante'], dtype=object)

# %% [markdown]
# Caso você faça a leitura e o carregamento do seu _dataframe_ sem usar o parâmetro `parse_dates`, a coluna _data_ virá como do tipo `object` (string)

# %%
fat.dtypes
# Out:
# data                       object
# estilo                     object
# quantidade de garrafas      int64
# preço da garrafa          float64
# total                     float64
# dtype: object

# %% [markdown]
# Então, chamamos o método `to_datetime` do __PANDAS__ para convertermos essa coluna para _datimetime_.

# %%
fat['data'] = pd.to_datetime(fat['data'])

# %% [markdown]
# Chamamos novamente o atributo `dtypes` para conferirmos se a conversão ocorreu com sucesso.
#
# Veja agora que a coluna _data_ está como `datetime64`.

# %%
fat.dtypes
# Out:
# data                      datetime64[ns]
# estilo                            object
# quantidade de garrafas             int64
# preço da garrafa                 float64
# total                            float64
# dtype: object

# %% [markdown]
# # Terminamos por hoje!
